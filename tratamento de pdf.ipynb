# %%
import pandas as pd
estoque = pd.read_excel('Estoque.xlsx')

# %%
estoque.head(20)
# Out:
#     Unnamed: 0 LISTA DE ESTOQUE DO ARMAZÉM         Unnamed: 2  \
# 0          NaN     VALOR TOTAL DO ESTOQUE:  ITENS DO ESTOQUE:
# 1          NaN                        4649                 11
# 2          NaN                         SKU          DESCRIÇÃO
# 3          NaN                      SP7875             Item 1
# 4          NaN                     TR87680             Item 2
# 5          NaN                    MK676554             Item 3
# 6          NaN                     YE98767             Item 4
# 7          NaN                     XR23423             Item 5
# 8          NaN                     PW98762             Item 6
# 9          NaN                     BM87684             Item 7
# 10         NaN                     BH67655             Item 8
# 11         NaN                     WT98768             Item 9
# 12         NaN                      TS3456            Item 10
# 13         NaN                      WDG123            Item 11
#
# ...

# %%
estoque.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   0 non-null      float64
#  1   LISTA DE ESTOQUE DO ARMAZÉM  14 non-null     object
#  2   Unnamed: 2                   14 non-null     object
#  3   Unnamed: 3                   14 non-null     object
#  4   Unnamed: 4                   13 non-null     object
#  5   Unnamed: 5                   13 non-null     object
#  6   Unnamed: 6                   12 non-null     object
#  7   Unnamed: 7                   12 non-null     object
#  8   Unnamed: 8                   12 non-null     object
#  9   Unnamed: 9                   12 non-null     object
#  10  Unnamed: 10                  12 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ KB
