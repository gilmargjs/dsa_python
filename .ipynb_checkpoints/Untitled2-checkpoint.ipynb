# %%
pl = open('pilaresache.csv','r')
data = pl.read()
columns['n(y)']
# Out:
# ['"INSPEÇÕES TOPOGRÁFICAS -  MONTAGEM DE PRÉ-MOLDADOS\nPO.QUA 010 - Verificação de Materiais e Serviços"', '', '', '', '', '', '', '', '', '\nCódigo da Peça,x,y,z,Projeto (m)', '"1ª Etapa- Real (m)\n(Antes do grauteamento do cálice)"', 'DATA,EXCENTRICIDADE', '" 2ª Etapa- Real (m)\n(Após o grauteamento do cálice)"', 'DATA,EXCENTRICIDADE', '"3ª Etapa- Real (m)\n(Após instalação das vigas)"', 'DATA\n', '', 'N (y),E (x),N (y),E (x)', 'N (y),E (x),N (y),E (x)', 'N (y),E (x),N (y),E (x),\n', '', '', '', '', '', '', '', '', '\nPP1,70,40', '"9084730,656","280045,053","9084730,655","280045,054",17/01/2021', ',"9084730,65","280045,056",18/01/2021', '', ',\nPP2,40,40', '"9084735,5385","280031,8435","9084735,5380","280031,89",9/28/2020', ',"9084735,5380","280031,891",9/28/2020', '', ',\nPP3,40,40', '"9084741,5385","280044,8913","9084741,5390","280044,89",17/01/2021', ',"9084741,5430","280044,888",18/01/2021', '', ',\nPP4,40,40', '"9084750,5385","280044,8913","9084750,5380","280044,89",9/8/2020',
# ...
